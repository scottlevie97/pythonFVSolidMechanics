# %% [markdown]
# # 3. **Internal Cells**
#
# [<svg style="color: rgb(53, 145, 243);" xmlns="http://www.w3.org/2000/svg" width="20" height="20" fill="currentColor" class="bi bi-arrow-left-circle-fill" viewBox="0 0 16 16"> <path d="M8 0a8 8 0 1 0 0 16A8 8 0 0 0 8 0zm3.5 7.5a.5.5 0 0 1 0 1H5.707l2.147 2.146a.5.5
# 0 0 1-.708.708l-3-3a.5.5 0 0 1 0-.708l3-3a.5.5 0 1 1 .708.708L5.707 7.5H11.5z" fill="#3591f3"></path> </svg> **Notebook 2** ](https://nbviewer.org/github/scottlevie97/pythonFVSolidMechanics/blob/new-release/lesson_notebooks/_02_Derivation_Discretistion.ipynb?flush_cache=true)
# |
# [**Notebook 4** <svg style="color: rgb(53, 145, 243);" xmlns="http://www.w3.org/2000/svg" width="20" height="20" fill="currentColor" class="bi bi-arrow-left-circle-fill" viewBox="0 0 16 16" transform="rotate(180)"> <path d="M8 0a8 8 0 1 0 0 16A8 8 0 0 0 8 0zm3.5 7.5a.5.5 0 0 1 0 1H5.707l2.147 2.146a.5.5
# 0 0 1-.708.708l-3-3a.5.5 0 0 1 0-.708l3-3a.5.5 0 1 1 .708.708L5.707 7.5H11.5z" fill="#3591f3"></path> </svg>](https://nbviewer.org/github/scottlevie97/pythonFVSolidMechanics/blob/new-release/lesson_notebooks/_04_Fixed_Displacement_BCs.ipynb?flush_cache=true)
#
# ***

# %% [markdown]
# The first type of cell to be fully discretised will be the cells which don't share a face with the boundary, i.e. internal cells. This means they will have a full stencil, i.e. a north, south, east and west cell. After these are discretised their $a$-terms and $b$-terms will be coded.
#
# The semi-discretised momentum equation we left off with in the previous notebook is:
#
# $x$-direction:
#
# $$
# \underbrace{
# \frac{\rho}{\Delta t^2} \left( u_P^n V^n \right)
# -
# \mu \left( \dfrac{\partial u}{\partial y} \right)
# _N |S_N|
# +
# \mu \left( \dfrac{\partial u}{\partial y} \right)
#  _S |S_S|
# -
# (2\mu + \lambda)
# \left(\dfrac{\partial u}{\partial x} \right)
#  _E |S_E|
# +
# (2\mu + \lambda)
# \left(\dfrac{\partial u}{\partial x}\right)
#  _W |S_W|
# }_{Unkown}
# =
# \underbrace{
# \frac{\rho}{\Delta t^2} \left( 2  u_P V - u_P^{oo} V^{oo} \right)
# +
# \mu \left( \dfrac{\partial v}{\partial x}  \right)
#  _N |S_N|
# -
# \mu \left( \dfrac{\partial v}{\partial x} \right)
# _S |S_S|
# +
# \lambda
# \left(\dfrac{\partial v}{\partial y}\right)
# _E |S_E|
# -
# \lambda
# \left(\dfrac{\partial v}{\partial y}\right)
# _W |S_W|
# }_{Known}
# $$
#
# $y$-direction:
#
# $$
# \underbrace{
# \frac{\rho}{\Delta t^2} \left(   v_P^n V^n \right)
# -
# (2\mu + \lambda)
# \left(\dfrac{\partial v}{\partial y}\right)
#  _N |S_N|
#  +
# (2\mu + \lambda)
# \left(\dfrac{\partial v}{\partial y} \right)
# _S |S_S|
# -
# \mu
# \left( \dfrac{\partial v}{\partial x}\right)
#  _E |S_E|
# +
# \mu
# \left( \dfrac{\partial v}{\partial x}\right)
#  _W |S_W|
# }_{Unkown}
# =
# \underbrace{
# \frac{\rho}{\Delta t^2} \left( 2  v_P V - v_P^{oo} V^{oo} \right)
# +
# (2\mu + \lambda)
# \left(\dfrac{\partial u}{\partial x} \right)
#  _N |S_N|
# -
# (2\mu + \lambda)
# \left(\dfrac{\partial u}{\partial x} \right)
# _S |S_S|
# +
# \mu
# \left( \dfrac{\partial u}{\partial y} \right)
# _E |S_E|
# -
# \mu
# \left(  \dfrac{\partial u}{\partial y} \right)
# _W |S_W|
# }_{Known}
# $$
#
# where the known terms are on the right hand side and the unknown terms on the left hand side.

# %% [markdown]
# ## Discretisation of Partial Derivatives
#
# The partial derivatives within the momentum equation are all located at a face centre. These will be approximated using central differencing.
#
# ### LHS (Unknown) Descretisation
#
# The discretisation of the unknown (LHS) partial derivatives in the $x$-equation $\left( \dfrac{\partial u}{\partial y}_N , \dfrac{\partial u}{\partial y}_S , \dfrac{\partial u}{\partial x}_E , \dfrac{\partial u}{\partial x}_W \right)$ and the $y$-equation $\left( \dfrac{\partial v}{\partial y}_N , \dfrac{\partial v}{\partial y}_S , \dfrac{\partial v }{\partial v}_E , \dfrac{\partial v}{\partial x}_W \right)$ are approximated as the difference between the displacement at cell P and the neighbouring cell, divided by the distance between them.
#
# **_Note on direction_** Positive $x$-direction is left to right, positive $y$-direction is down to up

# %% [markdown]
# <img src="./paper_images/mesh_displacements.png" alt="Drawing" style="width: 600px;"/>
# <img src="./paper_images/partial_derivatives_mesh.png" alt="Drawing" style="width: 600px;"/>

# %% [markdown]
# #### $x$-equation:
#
# $$
# \frac{\rho}{\Delta t^2} \left( u_p^n V^n \right)
# -
# \mu \left( \dfrac{\partial u}{\partial y} \right)
# _N |S_N|
# +
# \mu \left( \dfrac{\partial u}{\partial y} \right)
#  _S |S_S|
# -
# (2\mu + \lambda)
# \left(\dfrac{\partial u}{\partial x} \right)
#  _E |S_E|
# +
# (2\mu + \lambda)
# \left(\dfrac{\partial u}{\partial x}\right)
#  _W |S_W|
# = RHS
# $$
#
# Discretising the partial derivatives gives:
#
# $$
# \frac{\rho}{\Delta t^2} \left( u_P^n V^n \right)
# -
# \mu \left( \dfrac{ u_N - u_P }{\Delta y} \right)
#  |S_N|
# +
# \mu \left( \dfrac{ u_P - u_S }{\Delta y} \right)
#   |S_S|
# -
# (2\mu + \lambda)
# \left(\dfrac{ u_E - u_P}{\Delta x} \right)
#   |S_E|
# +
# (2\mu + \lambda)
# \left(\dfrac{ u_P - u_W}{\Delta x}\right)
#   |S_W|
# =
# RHS
# $$
#
# Grouping in terms of $u_P$, $u_N$, $u_S$, $u_E$ & $u_W$:
#
# $$
# u_P \left[
# \frac{\rho}{\Delta t^2} V^n
# +
# \dfrac{\mu |S_N|}{\Delta y}
# +
# \dfrac{\mu_ |S_S|}{\Delta y}
# +
# \dfrac{(2\mu + \lambda) |S_E|}{\Delta x}
# +
# \dfrac{(2\mu + \lambda) |S_W|}{\Delta x}
# \right]
# -
# u_N \dfrac{\mu |S_N|}{\Delta y}
# -
# u_S \dfrac{\mu |S_S|}{\Delta y}
# -
# u_E \dfrac{(2\mu + \lambda) |S_E|}{\Delta x}
# -
# u_W \dfrac{(2\mu + \lambda) |S_W|}{\Delta x}
# =
# RHS
# $$

# %% [markdown]
# #### $y$-equation:
#
# $$
# \frac{\rho}{\Delta t^2} \left(   v_p^n V^n \right)
# -
# (2\mu + \lambda)
# \left(\dfrac{\partial v}{\partial y}\right)
#  _N |S_N|
# +
# (2\mu + \lambda)
# \left(\dfrac{\partial v}{\partial y} \right)
# _S |S_S|
# -
# \mu
# \left( \dfrac{\partial v}{\partial x}\right)
#  _E |S_E|
# +
# \mu
# \left( \dfrac{\partial v}{\partial x}\right)
#  _W |S_W|
# = RHS
# $$
#
# Discretising the partial derivatives gives:
#
#
# $$
# \frac{\rho}{\Delta t^2} \left(   v_p^n V^n \right)
# -
# (2\mu + \lambda)
# \left(\dfrac{v_N - v_P}{\Delta y}\right)
# |S_N|
# +
# (2\mu + \lambda)
# \left(\dfrac{v_P - v_S}{\Delta y} \right)
# |S_S|
# -
# \mu
# \left( \dfrac{v_E - v_P}{\Delta x}\right)
# |S_E|
# +
# \mu
# \left( \dfrac{v_P - v_W}{\Delta x}\right)
# |S_W|
# =
# RHS
# $$
#
# Grouping in terms of $v_P$, $v_N$, $v_S$, $v_E$ & $v_W$:
#
# $$
# v_P \left[
# \frac{\rho}{\Delta t^2} V^n
# +
# \dfrac{(2\mu + \lambda)  |S_N|}{\Delta y}
# +
# \dfrac{(2\mu + \lambda)  |S_S|}{\Delta y}
# +
# \dfrac{\mu |S_E|}{\Delta x}
# +
# \dfrac{\mu |S_W|}{\Delta x}
# \right]
# -
# v_N \dfrac{(2\mu + \lambda) |S_N|}{\Delta y}
# -
# v_S \dfrac{(2\mu + \lambda) |S_S|}{\Delta y}
# -
# v_E \dfrac{\mu |S_E|}{\Delta x}
# -
# v_W \dfrac{\mu |S_W|}{\Delta x}
# =
# RHS
# $$

# %% [markdown]
# ### RHS (Known) Discretisation

# %% [markdown]
# The descretization of the kown (RHS) partial derivatives in the $x$-equation $\left( \dfrac{\partial v}{\partial x}_N , \dfrac{\partial x}{\partial x}_S , \dfrac{\partial v}{\partial y}_E , \dfrac{\partial v}{\partial y}_W \right)$ and the $y$-equation $\left( \dfrac{\partial u}{\partial x}_N , \dfrac{\partial u}{\partial x}_S , \dfrac{\partial u }{\partial y}_E , \dfrac{\partial u}{\partial y}_W \right)$ are slightly more complicated. This is because the direction of change of parallel to the face surface. This will require using more cell displacement.
#
# Firstly, we need to approximate the displacement values are the cell corner (blue below). From this, we approximate the partial derivative at the face centre as the difference between the corner values divided by the distance between them:
#
# <img src="./paper_images/cornerDisplacements.png" alt="Drawing" style="width: 600px;"/>
# <img src="./paper_images/unkownDerivation.png" alt="Drawing" style="width: 600px;"/>
#
# The corner displacement values are approximated as the average of the cell centres displacements of the surrounding cells:
#
# <img src="./paper_images/unkownDerivation_2.png" alt="Drawing" style="width: 600px;"/>

# %% [markdown]
# #### $x$-equation:
#
# $$
# LHS =
# \frac{\rho}{\Delta t^2} \left( 2  u_p V - u_p^{oo} V^{oo} \right)
# +
# \mu \left( \dfrac{\partial v}{\partial x}  \right)
#  _N |S_N|
# -
# \mu \left( \dfrac{\partial v}{\partial x} \right)
# _S |S_S|
# +
# \lambda
# \left(\dfrac{\partial v}{\partial y}\right)
# _E |S_E|
# -
# \lambda
# \left(\dfrac{\partial v}{\partial y}\right)
# _W |S_W|
# $$
#
# Discretising the partial derivatives gives:
#
#
# $$
# LHS =
# \frac{\rho}{\Delta t^2} \left( 2  u_p V - u_p^{oo} V^{oo} \right)
# +
# \mu \left( \dfrac{{v_{NE}}_c - {v_{NW}}_c}{\Delta x}  \right)
# |S_N|
# -
# \mu \left( \dfrac{{v_{SE}}_c - {v_{SW}}_c}{\Delta x}  \right)
# _S |S_S|
# +
# \lambda
# \mu \left( \dfrac{{v_{NE}}_c - {v_{SE}}_c}{\Delta y}  \right)
# _E |S_E|
# -
# \lambda
# \mu \left( \dfrac{{v_{NW}}_c - {v_{SW}}_c}{\Delta y}  \right)
# _W |S_W|
# $$

# %% [markdown]
# #### $y$-equation:
#
# $$
# LHS =
# \frac{\rho}{\Delta t^2} \left( 2  v_p V - v_p^{oo} V^{oo} \right)
# +
# (2\mu + \lambda)
# \left(\dfrac{\partial u}{\partial x} \right)
#  _N |S_N|
# -
# (2\mu + \lambda)
# \left(\dfrac{\partial u}{\partial x} \right)
# _S |S_S|
# +
# \mu
# \left( \dfrac{\partial u}{\partial y} \right)
# _E |S_E|
# -
# \mu
# \left(  \dfrac{\partial u}{\partial y} \right)
# _W |S_W|
# $$
#
# Discretising the partial derivatives gives:
#
#
# $$
# LHS =
# \frac{\rho}{\Delta t^2} \left( 2  v_p V - v_p^{oo} V^{oo} \right)
# +
# (2\mu + \lambda)
# \left( \dfrac{{u_{NE}}_c - {u_{NW}}_c}{\Delta x}  \right)
#  _N |S_N|
# -
# (2\mu + \lambda)
# \left( \dfrac{{u_{SE}}_c - {u_{SW}}_c}{\Delta x}  \right)
# _S |S_S|
# +
# \mu
# \left( \dfrac{{u_{NE}}_c - {u_{SE}}_c}{\Delta y}  \right)
# _E |S_E|
# -
# \mu
# \left( \dfrac{{u_{NW}}_c - {u_{SW}}_c}{\Delta y}  \right)
# _W |S_W|
# $$

# %% [markdown]
# ## Fully Discretised Momentum Equations:
#
# Combining all this together we can form the fully discretised momentum equations:

# %% [markdown]
# $x$-equation:
#
# $$
# \frac{\rho}{\Delta t^2} \left( u_P^n V^n \right)
# -
# \mu \left( \dfrac{ u_N - u_P }{\Delta y} \right)
#  |S_N|
# +
# \mu \left( \dfrac{ u_P - u_S }{\Delta y} \right)
#   |S_S|
# -
# (2\mu + \lambda)
# \left(\dfrac{ u_E - u_P}{\Delta x} \right)
#   |S_E|
# +
# (2\mu + \lambda)
# \left(\dfrac{ u_P - u_W}{\Delta x}\right)
#   |S_W|
# \\ =
# \frac{\rho}{\Delta t^2} \left( 2  u_p V - u_p^{oo} V^{oo} \right)
# +
# \mu \left( \dfrac{{v_{NE}}_c - {v_{NW}}_c}{\Delta x}  \right)
# |S_N|
# -
# \mu \left( \dfrac{{v_{SE}}_c - {v_{SW}}_c}{\Delta x}  \right)
# _S |S_S|
# +
# \lambda
# \mu \left( \dfrac{{v_{NE}}_c - {v_{SE}}_c}{\Delta y}  \right)
# _E |S_E|
# -
# \lambda
# \mu \left( \dfrac{{v_{NW}}_c - {v_{SW}}_c}{\Delta y}  \right)
# _W |S_W|
# $$

# %% [markdown]
# $y$-equation:
#
# $$
# \frac{\rho}{\Delta t^2} \left(   v_p^n V^n \right)
# -
# (2\mu + \lambda)
# \left(\dfrac{v_N - v_P}{\Delta y}\right)
# |S_N|
# +
# (2\mu + \lambda)
# \left(\dfrac{v_P - v_S}{\Delta y} \right)
# |S_S|
# -
# \mu
# \left( \dfrac{v_E - v_P}{\Delta x}\right)
# |S_E|
# +
# \mu
# \left( \dfrac{v_P - v_W}{\Delta x}\right)
# |S_W| \\
# =
# \frac{\rho}{\Delta t^2} \left( 2  v_p V - v_p^{oo} V^{oo} \right)
# +
# (2\mu + \lambda)
# \left( \dfrac{{u_{NE}}_c - {u_{NW}}_c}{\Delta x}  \right)
#  _N |S_N|
# -
# (2\mu + \lambda)
# \left( \dfrac{{u_{SE}}_c - {u_{SW}}_c}{\Delta x}  \right)
# _S |S_S|
# +
# \mu
# \left( \dfrac{{u_{NE}}_c - {u_{SE}}_c}{\Delta y}  \right)
# _E |S_E|
# -
# \mu
# \left( \dfrac{{u_{NW}}_c - {u_{SW}}_c}{\Delta y}  \right)
# _W |S_W|
# $$

# %% [markdown]
# Now that we have a fully discretised equation we can begin to write each term into some code:

# %% [markdown]
# ## Temporal Terms:
#
# The temporal terms (terms that contain a function of time $t$) are as follows:
#
#
# LHS:
#
# $\frac{\rho}{\Delta t^2} \left( u_p^n V^n \right)$,
# $\frac{\rho}{\Delta t^2} \left( v_p^n V^n \right)$
#
# RHS:
#
# $\frac{\rho}{\Delta t^2} \left( 2  u_p V - u_p^{oo} V^{oo} \right)$,
# $\frac{\rho}{\Delta t^2} \left( 2  v_p V - v_p^{oo} V^{oo} \right)$
#
# Let's code the variables that are needed:

# %%
import numpy as np

# Density (kg/m^3) -> using a similar value to steel
rho = 8050

# Timestep size (s)
dt = 1

# Set Geometry
nx, ny = 40, 4
Lx, Ly = 2, 0.1

# Displacement fields -> this will the displacement values in the x and y direction for each point on the mesh
# All initial values are set to zero

from functions.Background_Functions import initialise_U_field

U_new = initialise_U_field(nx, ny)
U_old = initialise_U_field(nx, ny)
U_old_old = initialise_U_field(nx, ny)

U_previous = U_new

# As we're using a structured mesh, we assume the volume of each CV remains constant
# Therefore: V_new = V_old = V_old_old = V (m^3)

dy = Ly/ny   # Length of each control volume in the $y$-direction
dx = Lx/nx   # Length of each control volume in the $x$-direction

# Cell volume
V = dx*dy

# %% [markdown]
# ## Force Term
#
# The formulas for the Shear Modulus $\mu$ and Lame Modulus $\lambda$ are given in terms of the Elastic Modulus $E$ and Poisson's ratio $v$:
#
# $$ \mu= \frac{E}{2(1+v)} $$
# $$ \lambda= \frac{v E}{(1+v)(1-2v)} $$

# %%
# Elastic Modulus (Pa)
E = 200*1e9

# Poissons Ratio
v = 0.3

# Shear Modulus (Pa)
mu_ = E/(2*(1+v))

# Lame Modulus (Pa)
lambda_ = (v*E)/((1+v)*(1-2*v))

# NOTE "lambda" is an internal function in python, hence "Lambda" is use as a variable name

# %% [markdown]
# ### Labelling Coefficients
#
# Returning to the momentum equation:
#
# $$
# \underbrace{ \frac{\rho}{\Delta t^2} \left(  \boldsymbol{U}_p^n V^n -2 \boldsymbol{U}_p V + \boldsymbol{U}_p^{oo} V^{oo} \right)}_{Temporal\space term}
# -
# \underbrace{
# \sum_{f=1}^{nFaces} \begin{bmatrix}
# (2\mu + \lambda)\dfrac{\partial u}{\partial x} + \lambda\dfrac{\partial v}{\partial y}
# &
# \mu \left( \dfrac{\partial v}{\partial x} + \dfrac{\partial u}{\partial y} \right)
# \\
# \mu \left( \dfrac{\partial v}{\partial x} + \dfrac{\partial u}{\partial y} \right)
# &
# (2\mu + \lambda)\dfrac{\partial v}{\partial y}
# +
# \lambda\dfrac{\partial u}{\partial x}
# \end{bmatrix}_f \cdot \boldsymbol{S_f}
# }_{Force\space term}
#  = 0
# $$
#
# which expands to:
#
# $$
# \frac{\rho}{\Delta t^2} \left(   \begin{bmatrix} u \\ v\end{bmatrix}_p^n V^n -2  \begin{bmatrix} u \\ v\end{bmatrix}_p V + \begin{bmatrix} u \\ v\end{bmatrix}_p^{oo} V^{oo} \right)
# -
# \begin{bmatrix}
# \mu \left( \dfrac{\partial v}{\partial x} + \dfrac{\partial u}{\partial y} \right)
# \\
# (2\mu + \lambda)\dfrac{\partial v}{\partial y} + \lambda\dfrac{\partial u}{\partial x}
# \end{bmatrix}_N   |S_N|
# -
# \begin{bmatrix}
#  - \mu \left( \dfrac{\partial v}{\partial x} + \dfrac{\partial u}{\partial y} \right)
# \\
#  - \left( (2\mu + \lambda)\dfrac{\partial v}{\partial y} + \lambda\dfrac{\partial u}{\partial x} \right)
# \end{bmatrix}_S   |S_S|
# -
# \begin{bmatrix}
# (2\mu + \lambda)\dfrac{\partial u}{\partial x} + \lambda\dfrac{\partial v}{\partial y}
# \\
# \mu \left( \dfrac{\partial v}{\partial x} + \dfrac{\partial u}{\partial y} \right)
# \end{bmatrix}_E   |S_E|
# -
# \begin{bmatrix}
# - \left((2\mu + \lambda)\dfrac{\partial u}{\partial x} + \lambda\dfrac{\partial v}{\partial y} \right)
# \\
# - \mu \left( \dfrac{\partial v}{\partial x} + \dfrac{\partial u}{\partial y} \right)
# \end{bmatrix}_W   |S_W|
# = 0
# $$
#
# Before each partial derivative there is a constant coefficient either: $(2 \mu + \lambda)$, $\lambda$ or $\mu$. Labelling these coefficients $K$ will allow us to avoid "hard coding" the values $\mu$ and $\lambda$ throughout our code. Each coefficient depends the surface face ($N$, $S$, $E$, $W$), the direction of displacement ($u$, $v$) and the direction of change ($x$, $y$):

# %% [markdown]
# $$
# \begin{bmatrix}
# (2\mu + \lambda)\dfrac{\partial u}{\partial x} + \lambda\dfrac{\partial v}{\partial y}
# &
# \mu \left( \dfrac{\partial v}{\partial x} + \dfrac{\partial u}{\partial y} \right)
# \\
# \mu \left( \dfrac{\partial v}{\partial x} + \dfrac{\partial u}{\partial y} \right)
# &
# (2\mu + \lambda)\dfrac{\partial v}{\partial y}
# +
# \lambda\dfrac{\partial u}{\partial x}
# \end{bmatrix}
# =
# \begin{bmatrix}
# (K_{E, W, u, x})\dfrac{\partial u}{\partial x} + (K_{E, W, v, x})\dfrac{\partial v}{\partial y}
# &
# (K_{N, S, v, x}) \dfrac{\partial v}{\partial x} + (K_{N, S, u, x}) \dfrac{\partial u}{\partial y}
# \\
# (K_{E, W, v, y})\dfrac{\partial v}{\partial x} + (K_{E, W, u, y})\dfrac{\partial u}{\partial y}
# &
# (K_{N, S, v, y})\dfrac{\partial v}{\partial y}
# +
# (K_{N, S, v, y})\dfrac{\partial u}{\partial x}
# \end{bmatrix}
# $$

# %% [markdown]
# using the format $K_{NSEW, uv, xy}$
#
# The first term refers to face: either $N$, $S$, $E$ or $W$
#
# The second term refers to the displacement direction: either $u$ or $v$
#
# The third term refers to the momentum equation direction: either $x$ or $y$

# %% [markdown]
# $$
# \frac{\rho}{\Delta t^2} \left(   \begin{bmatrix} u \\ v\end{bmatrix}_p^n V^n -2  \begin{bmatrix} u \\ v\end{bmatrix}_p V + \begin{bmatrix} u \\ v\end{bmatrix}_p^{oo} V^{oo} \right)
# -
# \begin{bmatrix}
# (K_{N, v, x}) \dfrac{\partial v}{\partial x}  + (K_{N, u, x}) \dfrac{\partial u}{\partial y}
# \\
# (K_{N, v, y})\dfrac{\partial v}{\partial y} + (K_{N, u, y})\dfrac{\partial u}{\partial x}
# \end{bmatrix}_N   |S_N|
# -
# \begin{bmatrix}
# (K_{S, v, x}) \dfrac{\partial v}{\partial x}  + (K_{S, u, x}) \dfrac{\partial u}{\partial y}
# \\
# (K_{S, v, y})\dfrac{\partial v}{\partial y} + (K_{S, u, y})\dfrac{\partial u}{\partial x}
# \end{bmatrix}_S   |S_S|
# -
# \begin{bmatrix}
# (K_{E, u, x})\dfrac{\partial u}{\partial x} + (K_{E, v, x})\dfrac{\partial v}{\partial y}
# \\
# (K_{E, v, y})  \dfrac{\partial v}{\partial x} + (K_{E, u, y}) \dfrac{\partial u}{\partial y}
# \end{bmatrix}_E   |S_E|
# -
# \begin{bmatrix}
# (K_{W, u, x})\dfrac{\partial u}{\partial x} + (K_{W, v, x})\dfrac{\partial v}{\partial y}
# \\
# (K_{W, v, y})  \dfrac{\partial v}{\partial x} + (K_{W, u, y}) \dfrac{\partial u}{\partial y}
# \end{bmatrix}_W   |S_W|
# = 0
# $$
#
# These are summarised as follows:

# %% [markdown]
# |       |        E/W         |        E/W         |        N/S         |        N/S         |
# | ----- | :----------------: | :----------------: | :----------------: | :----------------: |
# |       |       **u**        |       **v**        |       **u**        |       **v**        |
# | **x** | $$K_{E, W, u, x}$$ | $$K_{E, W, v, x}$$ | $$K_{N, S, u, x}$$ | $$K_{N, S, v, x}$$ |
# | **y** | $$K_{E, W, u, y}$$ | $$K_{E, W, v, y}$$ | $$K_{N, S, u, y}$$ | $$K_{N, S, v, y}$$ |

# %% [markdown]
# |       |         E/W         |     E/W     |     N/S     |        N/S         |
# | ----- | :-----------------: | :---------: | :---------: | :----------------: |
# |       |        **u**        |    **v**    |    **u**    |       **v**        |
# | **x** | $$2\mu + \lambda $$ | $$\lambda$$ |   $$\mu$$   |      $$\mu$$       |
# | **y** |       $$\mu$$       |   $$\mu$$   | $$\lambda$$ | $$2\mu + \lambda$$ |

# %% [markdown]
# N/S and E/W have the same modulus value coefficients, however, N and E are positive and S and W are negative

# %% [markdown]
# Creating a coeficient function:

# %%
import numpy as np

def coef(xy, face, uv):

    coef = np.zeros((2, 2, 2))
    # i = E/W, N/S
    # j = u, v
    # k = x, y

    coef[0, 0, 0] = 2*mu_ + lambda_      # E/W, u, x
    coef[0, 0, 1] = mu_                  # E/W, u, y
    coef[0, 1, 0] = lambda_              # E/W, v, x
    coef[0, 1, 1] = mu_                  # E/W, v, y
    coef[1, 0, 0] = mu_                  # N/S, u, x
    coef[1, 0, 1] = lambda_              # N/S, u, y
    coef[1, 1, 0] = mu_                  # N/S, v, x
    coef[1, 1, 1] = 2*mu_ + lambda_      # N/S, v, y

    if (face == "E") | ((face == "W")):
        i = 0
    elif (face == "N") | ((face == "S")):
        i = 1
    if uv == "u":
        j = 0
    elif uv == "v":
        j = 1
    if xy == "x":
        k = 0
    elif xy == "y":
        k = 1

    return coef[i, j, k]

# %% [markdown]
# ## $A$-matrix

# %% [markdown]
# Identifying $a_P$, $a_N$, $a_S$, $a_E$ & $a_W$ in the momentum equation in the $x$-direction:
#
# $$
# u_P
# \underbrace{\left[
# \frac{\rho}{\Delta t^2} V^n
# +
# \dfrac{\mu |S_N|}{\Delta y}
# +
# \dfrac{\mu_ |S_S|}{\Delta y}
# +
# \dfrac{(2\mu + \lambda) |S_E|}{\Delta x}
# +
# \dfrac{(2\mu + \lambda) |S_W|}{\Delta x}
# \right]}_{a_P}
# -
# u_N
# \underbrace{\dfrac{\mu |S_N|}{\Delta y}}_{a_N}
# -
# u_S
# \underbrace{\dfrac{\mu |S_S|}{\Delta y}}_{a_S}
# -
# u_E
# \underbrace{\dfrac{(2\mu + \lambda) |S_E|}{\Delta x}}_{a_E}
# -
# u_W
# \underbrace{\dfrac{(2\mu + \lambda) |S_W|}{\Delta x}}_{a_W}
# =
# RHS
# $$
#
# $$
# a_P = \left[
# \frac{\rho}{\Delta t^2} V^n
# +
# \dfrac{\mu |S_N|}{\Delta y}
# +
# \dfrac{\mu |S_S|}{\Delta y}
# +
# \dfrac{(2\mu + \lambda) |S_E|}{\Delta x}
# +
# \dfrac{(2\mu + \lambda) |S_W|}{\Delta x}
# \right]
# $$
#
# $$
#
# \begin{align*}
# a_N & = \dfrac{\mu |S_N|}{\Delta y} & = & &(K_{N, u, x}) \dfrac{|S_N|}{\Delta y} \\
#
# a_S & = \dfrac{\mu |S_S|}{\Delta y} & = & &(K_{S, u, x}) \dfrac{|S_S|}{\Delta y} \\
#
# a_E & = \dfrac{(2\mu + \lambda) |S_E|}{\Delta x} & = & &(K_{E, u, x}) \dfrac{|S_E|}{\Delta x} \\
#
# a_W & = \dfrac{(2\mu + \lambda) |S_W|}{\Delta x} & = & &(K_{W, u, x}) \dfrac{|S_W|}{\Delta x} \\
# \end{align*}
# $$
#
# $$
# a_P = \left[
# \frac{\rho}{\Delta t^2} V^n
# +
# a_N
# +
# a_S
# +
# a_E
# +
# a_W
# \right]
# $$

# %%
# Surface area vectors

S_N = Sfy = dx
S_S = Sfy = dx
S_E = Sfx = dy
S_W = Sfx = dy

# %%
# a terms

a_N_x = (mu_)*S_N/dy
a_S_x = (mu_)*S_S/dy
a_E_x = (2*mu_ + lambda_)*S_E/dx
a_W_x = (2*mu_ + lambda_)*S_W/dx

# Similarly this can be written using the coef function

a_N_x = + coef("x", "N", "u")*(S_N)/dy
a_S_x = + coef("x", "S", "u")*(S_S)/dy
a_E_x = + coef("x", "E", "u")*(S_E)/dx
a_W_x = + coef("x", "W", "u")*(S_W)/dx

a_P_x = rho*dx*dy/(dt**2) + a_N_x + a_S_x + a_E_x + a_W_x

# %% [markdown]
# Identifying $a_P$, $a_N$, $a_S$, $a_E$ & $a_W$ in the momentum equation in the $y$-direction:
#
# $$
# v_P
# \underbrace{
# \left[
# \frac{\rho}{\Delta t^2} V^n
# +
# \dfrac{(2\mu + \lambda)  |S_N|}{\Delta y}
# +
# \dfrac{(2\mu + \lambda)  |S_S|}{\Delta y}
# +
# \dfrac{\mu |S_E|}{\Delta x}
# +
# \dfrac{\mu |S_W|}{\Delta x}
# \right]
# }_{a_P}
# -
# v_N \underbrace{\dfrac{(2\mu + \lambda) |S_N|}{\Delta y}}_{a_N}
# -
# v_S \underbrace{\dfrac{(2\mu + \lambda) |S_S|}{\Delta y}}_{a_S}
# -
# v_E \underbrace{\dfrac{\mu |S_E|}{\Delta x}}_{a_E}
# -
# v_W \underbrace{\dfrac{\mu |S_W|}{\Delta x}}_{a_W}
# =
# RHS
# $$
#
#
# $$
# a_P  = \left[
# \frac{\rho}{\Delta t^2} V^n
# +
# \dfrac{(2\mu + \lambda)  |S_N|}{\Delta y}
# +
# \dfrac{(2\mu + \lambda)  |S_S|}{\Delta y}
# +
# \dfrac{\mu |S_E|}{\Delta x}
# +
# \dfrac{\mu |S_W|}{\Delta x}
# \right]
# $$
#
# $$
# \begin{align*}
#
# a_N &=  \dfrac{(2\mu + \lambda) |S_N|}{\Delta y} &=&  &(K_{N, v, y}) \dfrac{|S_N|}{\Delta y}&  \\
#
# a_S &=  \dfrac{(2\mu + \lambda) |S_S|}{\Delta y} &=& &(K_{S, v, y}) \dfrac{|S_S|}{\Delta y}&  \\
#
# a_E &=  \dfrac{\mu |S_E|}{\Delta x}  &=&  &(K_{E, v, y}) \dfrac{|S_E|}{\Delta x}& \\
#
# a_W &=  \dfrac{\mu |S_W|}{\Delta x}  &=&  &(K_{W, v, y}) \dfrac{|S_W|}{\Delta x}& \\
#
# \end{align*}
# $$
#
# $$
# a_P  = \left[
# \frac{\rho}{\Delta t^2} V^n
# +
# a_N
# +
# a_S
# +
# a_E
# +
# a_W
# \right]
# $$

# %%
# a terms

a_N_y = (2*mu_ + lambda_)*S_N/dy
a_S_y = (2*mu_ + lambda_)*S_S/dy
a_E_y = (mu_) * S_E/dx
a_W_y = (mu_) * S_W/dx

# Similarly this can be written using the coef function

a_N_y = + coef("y", "N", "v")*(S_N)/dy
a_S_y = + coef("y", "S", "v")*(S_S)/dy
a_E_y = + coef("y", "E", "v")*(S_E)/dx
a_W_y = + coef("y", "W", "v")*(S_W)/dx

a_P_y = rho*dx*dy/(dt**2) + a_N_y + a_S_y + a_E_y + a_W_y

# %% [markdown]
# Now to create the A matrix we loop through each row in the A matrix (where each row referes to a point in the mesh) and assign the $a$ terms in their corresponding positions:
#
# Remembering the $x$ and $y$ equations take the form:
#
# **$x$-equation:**
#
# $u_P  a_P - u_N a_N - u_S a_S - u_E a_E - u_W a_W=b$
#
# **$y$-equation:**
#
# $v_P  a_P - v_N a_N - v_S a_S - v_E a_E - v_W a_W=b$

# %%
from functions.Background_Functions import cell_index


def createMatrix():

    # Initialise A matrix with zeros

    from scipy.sparse import csr_matrix

    # A_shell = csr_matrix(((ny+2)*(nx+2), (ny+2)*(nx+2))).toarray()
    A_shell = np.zeros([ny*nx, ny*nx])

    A_no_boundary_x = A_shell
    A_no_boundary_y = A_shell

    # Loop through each point in matrix
    for k in range(0, ny*nx):

        # This applies the a terms to call cells not on the boundary

        # Momentum equation:
        # u_Pa_P - u_Na_N - u_Sa_S - u_Ea_E - u_Wa_W = b
        if cell_index().no_boundary(k):

            A_no_boundary_x[k, k] = a_P_x
            A_no_boundary_x[k, index(k).n] = -a_N_x
            A_no_boundary_x[k, index(k).s] = -a_S_x
            A_no_boundary_x[k, index(k).e] = -a_E_x
            A_no_boundary_x[k, index(k).w] = -a_W_x

            A_no_boundary_y[k, k] = a_P_y
            A_no_boundary_y[k, index(k).n] = -a_N_y
            A_no_boundary_y[k, index(k).s] = -a_S_y
            A_no_boundary_y[k, index(k).e] = -a_E_y
            A_no_boundary_y[k, index(k).w] = -a_W_y

    return A_no_boundary_x, A_no_boundary_y

# %% [markdown]
# Now we have a function we can call that produces an A matrix for the x and $y$-equation with the terms filled for cells with no boundaries.
#
# Now we need to code the 1D $b$-matrix

# %% [markdown]
# ## $b$-matrix
#
# The b-matrix will comprise of the RHS of the momentum equation. This side is comprised of known values, meaning the displacements are taken from the solution in the previous iteration.

# %% [markdown]
# Firstly we need to write a function that approximates the displacement ($u$, $v$) values at the corner of each cell. Previously we described this as the average of the displacements of cell centres of the surrounding cells.

# %%
from functions.Background_Functions import displacement

# U_array is the 2D array for the U field


def corner(corner_placement, uv, U_array, k):
    if uv == "u":
        uv_i = 0
    elif uv == "v":
        uv_i = 1

    # The displacement function returns the u or v values (uv_i) for a particular cell (k) within a displacement field (U_array)
    # disp below is the u or v value at cell k
    disp = displacement(k, U_array, uv_i)

    if corner_placement == "NE":
        return (1/4)*(disp.P + disp.NE + disp.N + disp.E)
    if corner_placement == "SE":
        return (1/4)*(disp.P + disp.SE + disp.S + disp.E)
    if corner_placement == "SW":
        return (1/4)*(disp.P + disp.SW + disp.S + disp.W)
    if corner_placement == "NW":
        return (1/4)*(disp.P + disp.NW + disp.N + disp.W)

# %% [markdown]
# Coding the following equations:
#
# ### $x$-equation:
#
# $$
# \frac{\rho}{\Delta t^2} \left( 2  u_p V - u_p^{oo} V^{oo} \right)
# +
# \mu \left( \dfrac{{v_{NE}}_c - {v_{NW}}_c}{\Delta x}  \right)
#  |S_N|
# -
# \mu \left( \dfrac{{v_{SE}}_c - {v_{SW}}_c}{\Delta x}  \right)
# _S |S_S|
# +
# \lambda \left( \dfrac{{v_{NE}}_c - {v_{SE}}_c}{\Delta y}  \right)
# _E |S_E|
# -
# \lambda \left( \dfrac{{v_{NW}}_c - {v_{SW}}_c}{\Delta y}  \right)
# _W |S_W|
# $$
#
# $$
# \frac{\rho}{\Delta t^2} \left( 2  u_p V - u_p^{oo} V^{oo} \right)
# +
# (K_{N, v, x}) \left( \dfrac{{v_{NE}}_c - {v_{NW}}_c}{\Delta x}  \right)
#  |S_N|
# -
# (K_{S, v, x}) \left( \dfrac{{v_{SE}}_c - {v_{SW}}_c}{\Delta x}  \right)
# _S |S_S|
# +
# (K_{E, v, x}) \left( \dfrac{{v_{NE}}_c - {v_{SE}}_c}{\Delta y}  \right)
# _E |S_E|
# -
# (K_{W, v, x}) \left( \dfrac{{v_{NW}}_c - {v_{SW}}_c}{\Delta y}  \right)
# _W |S_W|
# $$

# %%
b_matrix_shell = np.zeros([(ny+2)*(nx+2), 1])

b_matrix_x = b_matrix_shell

# Loop through each row in the b_matrix
for k in np.arange(0, (nx+2)*(ny+2)):

    if cell_index().no_boundary(k):

        b_matrix_x[k] = (rho/(dt**2))*(2*(U_old[k, 0])*dx*dy - U_old_old[k, 0]*dx*dy) + (
            + mu_*(corner("NE", "v", U_previous, k) -
                   corner("NW", "v", U_previous, k))
            - mu_*(corner("SE", "v", U_previous, k) -
                   corner("SW", "v", U_previous, k))
            + lambda_*(corner("NE", "v", U_previous, k) -
                       corner("SE", "v", U_previous, k))
            - lambda_*(corner("NW", "v", U_previous, k) -
                       corner("SW", "v", U_previous, k))
        )

# %% [markdown]
# ### $y$-equation:
#
# $$
# \frac{\rho}{\Delta t^2} \left( 2  v_p V - v_p^{oo} V^{oo} \right)
# +
# (2\mu + \lambda)
# \left( \dfrac{{u_{NE}}_c - {u_{NW}}_c}{\Delta x}  \right)
#  _N |S_N|
# -
# (2\mu + \lambda)
# \left( \dfrac{{u_{SE}}_c - {u_{SW}}_c}{\Delta x}  \right)
# _S |S_S|
# +
# \mu
# \left( \dfrac{{u_{NE}}_c - {u_{SE}}_c}{\Delta y}  \right)
# _E |S_E|
# -
# \mu
# \left( \dfrac{{u_{NW}}_c - {u_{SW}}_c}{\Delta y}  \right)
# _W |S_W|
# $$
#
# $$
# \frac{\rho}{\Delta t^2} \left( 2  v_p V - v_p^{oo} V^{oo} \right)
# +
# (K_{N, u, y})
# \left( \dfrac{{u_{NE}}_c - {u_{NW}}_c}{\Delta x}  \right)
#  _N |S_N|
# -
# (K_{S, u, y})
# \left( \dfrac{{u_{SE}}_c - {u_{SW}}_c}{\Delta x}  \right)
# _S |S_S|
# +
# (K_{N, u, y})
# \left( \dfrac{{u_{NE}}_c - {u_{SE}}_c}{\Delta y}  \right)
# _E |S_E|
# -
# (K_{N, u, y})
# \left( \dfrac{{u_{NW}}_c - {u_{SW}}_c}{\Delta y}  \right)
# _W |S_W|
# $$

# %%
b_matrix_y = b_matrix_shell

# Loop through each row in the b_matrix
for k in np.arange(0, (nx+2)*(ny+2)):

    if cell_index().no_boundary(k):

        b_matrix_y[k] = (rho/(dt**2))*(2*(U_old[k, 1])*dx*dy - U_old_old[k, 1]*dx*dy) + (
            + (2*mu_ + lambda_)*(corner("NE", "u", U_previous, k) -
                                 corner("NW", "u", U_previous, k))
            - (2*mu_ + lambda_)*(corner("SE", "u", U_previous, k) -
                                 corner("SW", "u", U_previous, k))
            + mu_*(corner("NE", "u", U_previous, k) -
                   corner("SE", "u", U_previous, k))
            - mu_*(corner("NW", "u", U_previous, k) -
                   corner("SW", "u", U_previous, k))
        )

# %% [markdown]
# Using the coefficient function, we can create a generalised b-term function:

# %%
# b temporal term
def b_temporal(U_old, U_old_old, k, xy):

    if xy == "x":
        b_temporal_term = (rho/(dt**2)) * \
            (2*(U_old[k, 0])*dx*dy - U_old_old[k, 0]*dx*dy)
    if xy == "y":
        b_temporal_term = (rho/(dt**2)) * \
            (2*(U_old[k, 1])*dx*dy - U_old_old[k, 1]*dx*dy)

    return b_temporal_term


def b_force(k, xy, U_previous):

    if xy == "x":
        uv = "v"
    if xy == "y":
        uv = "u"

    b_force = (
        S_N*A.coef(xy, "N", uv)*(
            (A.corner("NE", uv, U_previous, k) -
             A.corner("NW", uv, U_previous, k))
            / dx)
        -
        S_S*A.coef(xy, "S", uv)*(
            (A.corner("SE", uv, U_previous, k) -
             A.corner("SW", uv, U_previous, k))
            / dx)
        +
        S_E*A.coef(xy, "E", uv)*(
            (A.corner("NE", uv, U_previous, k) -
             A.corner("SE", uv, U_previous, k))
            / dy)
        -
        S_W*A.coef(xy, "W", uv)*(
            (A.corner("NW", uv, U_previous, k) -
             A.corner("SW", uv, U_previous, k))
            / dy)
    )

    return b_force

# %% [markdown]
# Let's now combine the A matrix coefficients and b-equation temporal and force terms into a single class. This way we will easily be able to point to the values. This will be shown later.

# %%
transient = False

# %%
from functions.Background_Functions import index

class A(index, displacement):

    def __init__(self, xy):

        if xy == "x":
            uv = "u"

        if xy == "y":
            uv = "v"

        self.a_N = + A.coef(xy, "N", uv)*(Sfy)/dy
        self.a_S = + A.coef(xy, "S", uv)*(Sfy)/dy
        self.a_E = + A.coef(xy, "E", uv)*(Sfx)/dx
        self.a_W = + A.coef(xy, "W", uv)*(Sfx)/dx

        if transient:
            self.a_P = (rho*dx*dy/(dt**2)) + self.a_N + \
                self.a_S + self.a_E + self.a_W
        else:
            self.a_P = self.a_N + self.a_S + self.a_E + self.a_W

    def createMatrix(self):

        A_no_boundary = np.zeros([ny*nx, ny*nx])

        for k in range(0, ny*nx):
            if cell_index().no_boundary(k):

                A_no_boundary[k, k] = self.a_P
                A_no_boundary[k, index(k).n] = -self.a_N
                A_no_boundary[k, index(k).s] = -self.a_S
                A_no_boundary[k, index(k).e] = -self.a_E
                A_no_boundary[k, index(k).w] = -self.a_W

        return A_no_boundary

    # b temporal term
    def b_temporal(U_old, U_old_old, k, xy):

        if xy == "x":
            if transient:
                b_temporal_term = (
                    rho/(dt**2))*(2*(U_old[k, 0])*dx*dy - U_old_old[k, 0]*dx*dy)
            else:
                b_temporal_term = 0

        if xy == "y":
            if transient:
                b_temporal_term = (
                    rho/(dt**2))*(2*(U_old[k, 1])*dx*dy - U_old_old[k, 1]*dx*dy)
            else:
                b_temporal_term = 0

        return b_temporal_term

    def b_force(k, xy, U_previous):

        if xy == "x":
            uv = "v"
        if xy == "y":
            uv = "u"

        b_force = (
            Sfy*A.coef(xy, "N", uv)*(
                (A.corner("NE", uv, U_previous, k) -
                 A.corner("NW", uv, U_previous, k))
                / dx)
            -
            Sfy*A.coef(xy, "S", uv)*(
                (A.corner("SE", uv, U_previous, k) -
                 A.corner("SW", uv, U_previous, k))
                / dx)
            +
            Sfx*A.coef(xy, "E", uv)*(
                (A.corner("NE", uv, U_previous, k) -
                 A.corner("SE", uv, U_previous, k))
                / dy)
            -
            Sfx*A.coef(xy, "W", uv)*(
                (A.corner("NW", uv, U_previous, k) -
                 A.corner("SW", uv, U_previous, k))
                / dy)
        )

        return b_force

    def corner(corner_placement, uv, U_previous, k):
        if uv == "u":
            uv_i = 0
        elif uv == "v":
            uv_i = 1

        disp = displacement(k, U_previous, uv_i)

        if corner_placement == "NE":
            return (1/4)*(disp.P + disp.NE + disp.N + disp.E)
        if corner_placement == "SE":
            return (1/4)*(disp.P + disp.SE + disp.S + disp.E)
        if corner_placement == "SW":
            return (1/4)*(disp.P + disp.SW + disp.S + disp.W)
        if corner_placement == "NW":
            return (1/4)*(disp.P + disp.NW + disp.N + disp.W)

    def coef(xy, face, uv):
        # could have and statements

        coef = np.zeros((2, 2, 2))
        # i = E/W, N/S
        # j = u, v
        # k = x, y

        coef[0, 0, 0] = 2*mu_ + lambda_      # E/W, u, x
        coef[0, 0, 1] = mu_                  # E/W, u, y
        coef[0, 1, 0] = lambda_              # E/W, v, x
        coef[0, 1, 1] = mu_                  # E/W, v, y
        coef[1, 0, 0] = mu_                  # N/S, u, x
        coef[1, 0, 1] = lambda_              # N/S, u, y
        coef[1, 1, 0] = mu_                  # N/S, v, x
        coef[1, 1, 1] = 2*mu_ + lambda_      # N/S, v, y

        if (face == "E") | ((face == "W")):
            i = 0
        elif (face == "N") | ((face == "S")):
            i = 1
        if uv == "u":
            j = 0
        elif uv == "v":
            j = 1
        if xy == "x":
            k = 0
        elif xy == "y":
            k = 1

        return coef[i, j, k]

# %% [markdown]
# ***
# [<svg style="color: rgb(53, 145, 243);" xmlns="http://www.w3.org/2000/svg" width="20" height="20" fill="currentColor" class="bi bi-arrow-left-circle-fill" viewBox="0 0 16 16"> <path d="M8 0a8 8 0 1 0 0 16A8 8 0 0 0 8 0zm3.5 7.5a.5.5 0 0 1 0 1H5.707l2.147 2.146a.5.5
# 0 0 1-.708.708l-3-3a.5.5 0 0 1 0-.708l3-3a.5.5 0 1 1 .708.708L5.707 7.5H11.5z" fill="#3591f3"></path> </svg> **Notebook 2** ](https://nbviewer.org/github/scottlevie97/pythonFVSolidMechanics/blob/new-release/lesson_notebooks/_02_Derivation_Discretistion.ipynb?flush_cache=true)
# |
# [**Notebook 4** <svg style="color: rgb(53, 145, 243);" xmlns="http://www.w3.org/2000/svg" width="20" height="20" fill="currentColor" class="bi bi-arrow-left-circle-fill" viewBox="0 0 16 16" transform="rotate(180)"> <path d="M8 0a8 8 0 1 0 0 16A8 8 0 0 0 8 0zm3.5 7.5a.5.5 0 0 1 0 1H5.707l2.147 2.146a.5.5
# 0 0 1-.708.708l-3-3a.5.5 0 0 1 0-.708l3-3a.5.5 0 1 1 .708.708L5.707 7.5H11.5z" fill="#3591f3"></path> </svg>](https://nbviewer.org/github/scottlevie97/pythonFVSolidMechanics/blob/new-release/lesson_notebooks/_04_Fixed_Displacement_BCs.ipynb?flush_cache=true)
#
# ***
